# %%
def question_1():
    num = int(input("enter a number:"))
    if num == 0:
        print("your number is zero")
        return
    first_property = "positive" if num > 0 else "negative"
    second_property = "even" if num%2==0 else "odd"
    print("your number is ",first_property," and ",second_property)
    return

def question_2():
     word = input("enter a string\n")
     letters = []
     for s in word:
         found=0
         for x in letters:
             if x[0] == s:
                 x[1] += 1
                 found=1
         if found == 0:
             letters.append([s,1])
     dict = {}
     for x in letters:
         dict.update({x[0]:x[1]})        
     print(dict)
     return    

def question_3():
    password = input("enter your password")
    if password == "":
        print("you did not enter a password")
    elif len(password) < 8:
        print("your password should be bigger than 8 characters")
    capital = False
    digit = False
    for w in password:
        if w.isdigit:
            digit = True
            break       
    for w in password:
        if not w.islower:
            capital = True
    if capital == False:
        print("your password must contain at least one capital letter")
    if digit == False:
        print("your password must contain at least one digit")

def question_4():
    listt = [12, 4, 9, 25, 30, 7, 18]
    sum = 0
    for num in listt:
        sum += num
    sum /= 7
    listt2 = []
    for num in listt:
        if num > sum:
            listt2.append(num)
    print(listt2)

def question_5():
    for i in range(0,6):
        print("*"*i,end="")
        print("\n")

def question_6():
    num = -1
    sum = 0
    count = 0
    while num != 0:
        num = int(input("enter a number\n"))
        sum += num
        count += 1
    sum /= count
    print("average of your numbers:")
    print(int(sum))

def question_7():
    word = input("enter a word\n")
    reverse = word[::-1]
    if word == reverse:
        print("your word is a palindrome")
    else:
        print("your wor is not a palindrome")    

def question_8():
    squares = []
    for i in range(0,101):
        if i % 3 == 0 and i % 5 == 0:
            squares.append(i*i)
    print(squares)        

def question_9():
    sentence = input("enter a sentence")
    words = sentence.split()
    for i in range(len(words)):
        words[i] = words[i].capitalize()
    print(words)

def movie_comments():
    total = int(input("enter total comment number\n"))
    comments = []
    for i in range (0,total+1):
        print("enter the ",i+1,". comment")
        comment = input()
        comments.append(comment)
    total_count = 0
    iyi_count = 0
    min = 100000
    max = 0
    longest_index = 0
    shortest_index = 0 
    for comment in comments:
        if comment.__contains__("iyi"):
            iyi_count += 1
        if len(comment) > max:
            max = len(comment)
            longest_index = comments.index(comment)
        if len(comment) > min:
            min = len(comment)
            shortest_index = comments.index(comment) 
        for char in comments:
            total_count += 1
    print("total count of comments: ",total)
    print("comments that contains the word \"iyi\":  ",iyi_count)
    print("longest comment is: ",comments[longest_index])
    print("shortest comment is: ",comments[shortest_index])
    print("average lenght: ",int(total_count/total))
